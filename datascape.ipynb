# %%
from bs4 import BeautifulSoup
import requests
import re
import csv
import time

# %%
soloPageUrl = 'https://www.yellow-pages.ph'

# %%
def add_spaces_after_punctuation(text):
    return re.sub(r'([,.;:!?)])([^\s])', r'\1 \2', text)

# %%
names = []
addresses = []
mobNumbers = []
ratingTot = []
averageStar = []
reviews = []
removedChar = [' ', '\n']
i = 21 # page number
steps = 30

while i <= steps:
    htmlText = 'https://www.yellow-pages.ph/category/commercial-properties/page-'
    temp = i
    htmlText = htmlText + str(temp)
    getHtml = requests.get(htmlText).text
    soup = BeautifulSoup(getHtml, 'lxml')
    # Searching for the whole result div
    businesses = soup.find_all('div', class_='search-listing')

    # Write the company names to a CSV file
    with open("broker.csv", "a", newline="") as file:
        writer = csv.writer(file)
        
        for business in businesses:
            # Access Page
            about = business.div.h2.a['href']
            
            # Page source
            pageUrl = soloPageUrl + about
            aboutUrl = requests.get(pageUrl).text
            soupPage = BeautifulSoup(aboutUrl, 'lxml')
            singlePage = soupPage.find_all('div', class_='yp-container')
            
            for page in singlePage:
                time.sleep(5)
                review_text = page.find('div', class_='yp-see-morex text-break')
                if review_text:
                    reviews.append(review_text.text.replace('\n', ''))
                else:
                    reviews.append('')
            
            time.sleep(10)
            # Search for name
            name = business.find('h2', class_='search-tradename').text.replace('\n', '')
            
            # Search for address
            address = business.find('span', class_='ellipsis').text
            
            # Search for mobile number
            mobile = business.find('a', class_='btn btn-yp-default mr-2 biz-btn-call yp-click')
            mobileNum = mobile['data-phone'] if mobile else ''
            
            # Search for average rating
            star_average = page.find('div', class_='rating-num')
            if star_average:
                star_average = star_average.text.replace('\n', '')
            else:
                star_average = ''
            
            if reviews:
                writer.writerow([name, address, mobileNum, star_average, reviews.pop(0)])
            else:
                writer.writerow([name, address, mobileNum, star_average, ''])
            
            print(name, "\n")
    print("Page", i, "& step", steps, "\n")
    time.sleep(5)
    i += 1
# Out:
# Our GlobalSpaces, Inc.
#
# P & J Building
#
# Page 1 Building
#
# Pascual L R And Sons
#
# Passenger Accident Management And Insurance Agency
#
# Pami
#
# Pen Brothers
#
# Perlas And Company
#
# Perlas Clinic
#
# Petaluma Properties, Incorporated
#
# Philamlife Tower
#
# Philexcel Business Center
#
# Philippine Axa Life Center
#
# Philippine Estates Corporation
#
# Philippine Estates Corporation
#
# Page 21 & step 30
#
# Philippine Estates Corporation
#
# Philippine Estates Corporation
#
# Philippine Estates Corporation
#
# Philippine Estates Corporation
#
# Philippine Estates Corporation
#
# Phes
#
# Pinnacle Real Estate Consulting Services
#
# Pioneer House
#
# Plaza Garcia
#
# Premiere Fiesta Land Incorporated
#
# Primary Industrial Properties Corporation
#
# Prime Corner Stone Ventures
#
# Prime Properties
#
# Primex Tower
#
# Pre Investment
#
# Page 22 & step 30
#
# Proaccess Business Services
#
# Project T Solutions
#
# Project T Solutions
#
# Propeller Realty
#
# Propertymart.Ph
#
# Provident International Resources
#
# Puyat G Building Administration Office
#
# Puzon's Office Building
#
# Queensland Commercial Plaza
#
# R And G Tirol Building
#
# Racitelcom
#
# Ramirez C And Company
#
# Ramirez C And Company
#
# Rcbc Plaza
#
# RDRDC
#
# Page 23 & step 30
#
# Rda Building Number 2 Administration
#
# Regina
#
# Regus Instant Offices Worldwide
#
# Regus Service Center
#
# Reliance Center
#
# Re/Max Premier Bgc
#
# Remedios Building Administration
#
# Renadar Development
#
# Ri-Rance Realty Corporation
#
# Richville Orate Tower
#
# Robinson Equitable Tower
#
# Robinsons Cyberscape Alpha
#
# Robinsons Cybergate Plaza
#
# Robinsons Luxuria
#
# The Rockwell Business Center
#
# Page 24 & step 30
#
# Rockwell Primaries
#
# The Vantage At Kapitolyo
#
# Rodel Barcelona Properties, Incorporated
#
# Romero Davin Realty And Services
#
# C.O.D Department Store
#
# Royal Arranque Commercial Center
#
# Royal Estate Xebu
#
# Royale Homes Marketing
#
# Rubysapphire Land Corp
#
# Rufino Pacific Tower
#
# S Medalla Building
#
# Sabiñano-De Guia Building Construction
#
# Salcedo Sky Suites
#
# San Antonio Condominium Builders, Incorporated
#
# San Antonio Condominium Builders
#
# Page 25 & step 30
#
# San Luis Building Administration
#
# Santos Knight Frank
#
# Sapat Realty Corporation
#
# Seascape Village
#
# SSSI
#
# Serendra - Umg
#
# Silanganan Towers  Corporation
#
# Silver Tree Real Estate Corporation
#
# Sky 1 Tower
#
# Sky Commercial Isulan
#
# Sm Development  Corporation
#
# Sm Development  Corporation
#
# Sm Development  Corporation
#
# Two E-Com Center
#
# Sm Offices
#
# Page 26 & step 30
#
# Solaris One
#
# Square B Commercial
#
# St Elizabeth Centre
#
# Stallworks
#
# Standard Realty  Corporation
#
# Standard Realty
#
# Starpager
#
# Storeys by Lessandra Developer
#
# Studio F Interior Design Services
#
# Summit Ridge Promenade
#
# Sun Miles Condominium
#
# Suntree Tower
#
# Sunview Palace
#
# TAG Resort - Resort and Leisure Complex
#
# Tan, Frankum & Associates
#
# Page 27 & step 30
#
# Tanlimco J B Y Sons Investment
#
# Tao Corporate Center
#
# Tarik Property Holdings, Incorporated
#
# Tarik Property Holdings, Incorporated
#
# Tcl Sun, Incorporated
#
# Tcl Sun, Incorporated
#
# The Astbury
#
# The Business Center
#
# The Columns
#
# The Fort Strip
#
# Fort Pointe Administration Office
#
# Tgbr
#
# The Nomad Offices Philippines
#
# The Office Project Ph
#
# The Oml Center
#
# Page 28 & step 30
#
# The Orient Square Condominium Association
#
# The Penbrothers International, Incorporated
#
# The Prestige Tower
#
# The Westpark Leisure Hub
#
# Time Realty
#
# Tivoli Garden Residences Corporation
#
# Tonette Realty & Family  Corporation
#
# Tonilyn Construction
#
# Top Frontier Investment Holdings, Inc.
#
# Topaz Realty And Development
#
# Toplite Development Corporation
#
# Topten Global LK Properties & Consultancy Inc
#
# Topten Global Lk Properties & Consultancy, Incorporated
#
# Torno Realty
#
# Toronto Commercial
#
# Page 29 & step 30
#
# Torrington Commercial Sales, Incorporated
#
# Total Corporate Network
#
# Total Performance Distibution
#
# Tpa Industrial
#
# Transphil Land  Corporation
#
# Sm Prime Holdings, Inc
#
# Un Tourist Arcade
#
# Union Bank
#
# Universal Tower
#
# Var Buildings, Incorporated
#
# Var Buildings
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 42
#      39     else:
#      40         reviews.append('')
# ---> 42 time.sleep(10)
#      43 # Search for name
#      44 name = business.find('h2', class_='search-tradename').text.replace('\n', '')
#
# KeyboardInterrupt:

# %%
i = 0
while i < 10:
    print("\n", "release me from mini boss", "\n")
    i += 1
    print("I am finished", "\n")
